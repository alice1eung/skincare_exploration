# %% [markdown]
# This is a Data Exploration on the asian beauty subreddit.  I will be exploring the posts asking for recommendations for products for specific skin types and exploring which products are the most recommended in the comments/replies section.
#
# I will specifically be looking at a few threads where the comments are structured since it is difficult to extract data from unstructured posts.  A future next step is to look into phrase mining research done by the University of Illinois or named entity recongition with a Stanford package to look at unstructured posts and significantly expand the quantity of data.

# %% [markdown]
# Import the necessary packages.  I initially had trouble importing praw because the notebook was running a different Python than the one in my command prompt so it could not find the import.  I fixed it by checking sys.executable and sys.path to see where the notebook is looking for imports and did path -m pip install praw.

# %%
#! usr/bin/env python3
import sys
import praw
import numpy as np
import pandas as pd 
import string
from datetime import datetime
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sys.executable
# Out:
# '/Users/alice1eung/anaconda3/bin/python'

# %% [markdown]
# Set up the Reddit API. I am looking at /r/AsianBeauty

# %%
reddit = praw.Reddit(client_id='14_CHARS_IDENTIFIER', 
                     client_secret='27_CHARS_SECRET_ID', 
                     user_agent='SCRIPT_NAME', 
                     username='REDDIT_USER_NAME', 
                     password='REDDIT_LOGIN_PASSWORD')

asian_beauty=reddit.subreddit('AsianBeauty')

# %% [markdown]
# Collect the Data from a few posts where the comments are structured.

# %%
dict = {"id" : [],
        "product" : [], 
        "step" : [],
        "opinion" : [],
        "thoughts" : [],
        "thread": []
}

submission = reddit.submission(id = '6lmzyl')

for comment in submission.comments:
    if(len(comment.body.split("\n\n")) >= 4 and comment.body[0] == "*"):
        dict["id"].append(comment.id)
        dict["product"].append(comment.body.split("\n\n")[0].replace("**",""))
        dict["step"].append(comment.body.split("\n\n")[1].replace("**",""))
        dict["opinion"].append(comment.body.split("\n\n")[2].replace("**",""))
        dict["thoughts"].append(comment.body.split("\n\n")[3].replace("**",""))  
        dict["thread"].append("Oily")
       
submission = reddit.submission(id = '6na9hw')
for comment in submission.comments:
    if(len(comment.body.split("\n\n")) >= 4):
        dict["id"].append(comment.id)
        dict["product"].append(comment.body.split("\n\n")[0].replace("**",""))
        dict["step"].append(comment.body.split("\n\n")[1].replace("**",""))
        dict["opinion"].append(comment.body.split("\n\n")[2].replace("**",""))
        dict["thoughts"].append(comment.body.split("\n\n")[3].replace("**",""))  
        dict["thread"].append("Dry")
        
submission = reddit.submission(id = '6uijtv')
for comment in submission.comments:
    if(len(comment.body.split("\n\n")) >= 4):
        dict["id"].append(comment.id)
        dict["product"].append(comment.body.split("\n\n")[0].replace("**",""))
        dict["step"].append(comment.body.split("\n\n")[1].replace("**",""))
        dict["opinion"].append(comment.body.split("\n\n")[2].replace("**",""))
        dict["thoughts"].append(comment.body.split("\n\n")[3].replace("**",""))  
        dict["thread"].append("Combination")
        
submission = reddit.submission(id = '6remns')
for comment in submission.comments:
    if(len(comment.body.split("\n\n")) >= 4):
        dict["id"].append(comment.id)
        dict["product"].append(comment.body.split("\n\n")[0].replace("**",""))
        dict["step"].append(comment.body.split("\n\n")[1].replace("**",""))
        dict["opinion"].append(comment.body.split("\n\n")[2].replace("**",""))
        dict["thoughts"].append(comment.body.split("\n\n")[3].replace("**",""))  
        dict["thread"].append("Acne")
        
data = pd.DataFrame(dict)
data
# Out:
#          id                                            product  \
# 0   djv0ax0                 Innisfree Super Volcanic Clay Mask
# 1   djv702q                                    Belif Aqua Bomb
# 2   djv01bn                                    Blotting Papers
# 3   djv4eeq     Missha Super Aqua Ultra Water-Full Clear Cream
# 4   djuzzcn                  Innisfree No Sebum Powder - Loose
# 5   djv05rw          Elizavecca 24K Gold Water Drop Cream Mask
# 6   djvlvej                           Pyungkang Yul Mist Toner
# 7   djvedyg            Cosrx Aloe Vera Oil-free Moisture Cream
# 8   djvpgxn        Zymogen Houttyunia Cordata Serum and Lotion
# 9   djv8nyi                          Neogen Black Volume Cream
# 10  djvkyzy        The History of Whoo Wrinkle Essentual Cream
# 11  djvkgfh            Shiseido Pureness Deep Cleansing Foam
# 12  djwf33s  Country & Stream Honey UV Water Gel SPF50+ PA++++
# 13  dk8cjho                              Hada Labo Perfect Gel
# 14  dk8mlx7                  Product name: Stratia Liquid Gold
# 15  dk8a8it                                        Rosehip Oil
# 16  dk870gv                          Pyukang Yul Essence Toner
# 17  dk9cye8                     Product: Mizon Black Snail AIO
# 18  dk8c0g5     PRODUCT NAME: Koh Gen Do Oriental Plants Soap
# 19  dk8c85m  PRODUCT NAME: Sulwhasoo Snowise EX Cleansing F...
# 20  dk8vqob   Lost and Found Seoul Med.Secret Cream + Ceramide
# 21  dk8mrvd      Botanic Farm Grain Ferment Cleansing Sherbet
# 22  dk80ops                Shiseido Ibuki Beauty Sleeping Mask
# 23  dk8bs0a     PRODUCT NAME: Shisheido Perfect Cleansing Oil
# 24  dk837ry  Shiseido Bio-Performance Advanced Super Revita...
# 25  dk9i3gu              PRODUCT Whamisa Organic Flowers Toner
# 26  dk8maj3              Innisfree Rice Sleeping Pack Capsule
# 27  dkirecs                     I'm from ginseng wash off mask
# 28  dk8bnmi          PRODUCT NAME: SK-II Facial Treatment Soap
# 29  dlt6v7f          Innisfree Bija Anti-Trouble Cleansing Gel
# 30  dlt7ebc                         Holika Holika 99% aloe gel
# 31  dlswn2m                 Su:m37 Miracle Rose Stick Cleanser
# 32  dlswt9s                 Innisfree Super Volcanic Clay Mask
# 33  dlt71q4          Banila co Miss Flower and Mr. Honey cream
# 34  dlswkk5   Elizavecca 24k Gold Waterdrop & 2hsam Cream Mask
# 35  dluk1za                     Mizon Snail Recovery Gel Cream
# 36  dlvkm71          Huxley Oil Essence Essence-Like, Oil-Like
# 37  dlzz95c          Benton Snail Bee High Content Steam Cream
# 38  dl4g1ts                          Cosrx Master Pimple Patch
# 39  dl4smbh                           Benton Snail Bee Essence
# 40  dl4fpug                               LJH Tea Tree Essence
# 41  dl4lm63                      Stratia Velvet Cleansing Milk
# 42  dl4mqbi                       CosRX Centella Blemish Cream
# 43  dl56j0g                          COSRX BHA Returning A-Sol
# 44  dl56o6v                           Scinic Snail AIO Ampoule
# 45  dl4fm93                 Innisfree Super Volcanic Clay Mask
# 46  dl4ft4h                                       Mizon 8% AHA
# 47  dl58nqw                       Cosrx 96 Snail Mucin Essence
# 48  dl53cf7              CosRX Acne One Step Pimple Clear Pads
# 49  dl80usl                            Aztec Healing Clay Mask
# 50  dl4o1c9  It's Skin Power 10 Formula VB Effector with Vi...
# 51  dl9doxx             Cosrx Good Morning Low pH Gel Cleanser
# 52  dl5zi0c                     Mizon Snail Recovery Gel Cream
# 53  dl4fyfm  Mizon Acence Blemish X Cream (I think, not at ...
# 54  dlguq74  Mandelic Acid- Dr. Wu's 18% AHA Skin Renewal S...
#
#                                       step  \
# 0                                Clay Mask
# 1                              Moisturizer
# 2                                    Tools
# 3                              Moisturizer
# 4                                  Make Up
# 5                              Moisturiser
# 6                          Hydrating toner
# 7                              Moisturizer
# 8                    Toner and moisturiser
# 9                Sleeping Pack/Moisturizer
# 10           Special needs/cream/eye cream
# 11                              Cleanser
# 12                               Sunscreen
# 13        \nMoisturiser (or Sleeping pack)
# 14  Step: moisturiser/last step occlusive
# 15                             Moisturizer
# 16                                   Toner
# 17                             Moisturizer
# 18                          STEP: CLEANSER
# 19                         STEP: Cleanser
# 20                           \nMoisturizer
# 21                      1st Step Cleanser
# 22                             Moisturiser
# 23                          STEP: CLEANSER
# 24                             Moisturizer
# 25                                  TONER
# 26                             Moisturizer
# 27                     Wash-off detox mask
# 28                         STEP: CLEANSER
# 29                                Cleanser
# 30                         Gel moisturizer
# 31                                Cleanser
# 32                               Clay Mask
# 33                               Occlusive
# 34                             Moisturiser
# 35                             Moisturizer
# 36                                 Essence
# 37                                   Cream
# 38                          Spot Treatment
# 39                                 Essence
# 40                                 Essence
# 41                         Second Cleanser
# 42                                   Cream
# 43                            Essence Step
# 44                                 Ampoule
# 45                               Clay Mask
# 46                      Chemical Exfoliant
# 47                                 Essence
# 48                      Chemical Exfoliant
# 49                                    Mask
# 50                                   Serum
# 51                         Second Cleanser
# 52                     Spot treatment step
# 53                              Spot Cream
# 54                                 Actives
#
#                                               opinion  \
# 0                                                Best
# 1                                                Best
# 2                                                Best
# 3                                                Best
# 4                                                Best
# 5                                                Best
# 6                                                Best
# 7                                                Best
# 8                                                Best
# 9                                                Best
# 10                                              Worst
# 11                                            WORST
# 12                                               Best
# 13                                            \nBEST
# 14                                               BEST
# 15  Best for immediate relief from stretches of he...
# 16  Best for my dear friend who has problematic dr...
# 17                                               Best
# 18                                               BEST
# 19                                               BEST
# 20                                             \nBest
# 21                                               Best
# 22                                              Worst
# 23                                             WORST
# 24                                        Best for me
# 25                                              WORST
# 26                                               Best
# 27                                               Best
# 28                                              WORST
# 29                                               Best
# 30                                               Best
# 31                                               Best
# 32                                               Best
# 33                                               Best
# 34                                               Best
# 35                                               Best
# 36                                               Best
# 37                                               Best
# 38                                               Best
# 39                                               Best
# 40                                              Best
# 41                                               Best
# 42                                               Best
# 43                                               Best
# 44                                               Best
# 45                                               Best
# 46                                               Best
# 47                                             Best
# 48                                             Best!!
# 49                                               Best
# 50                                               Best
# 51                                               Best
# 52                                               Best
# 53                                               Best
# 54                                               Best
#
#                                              thoughts       thread
# 0   Thoughts I use a clay mask at least once a wee...         Oily
# 1   I love this stuff. It's a gel cream that sinks...         Oily
# 2   Thoughts Not really a product as such, but I s...         Oily
# 3   Thoughts Using this gel-type moisturizer at ni...         Oily
# 4   Thoughts Love this affordable powder! I dust i...         Oily
# 5   Thoughts This is a lightweight gel from Elizav...         Oily
# 6   Thoughts: This product is how I'm surviving su...         Oily
# 7   Thoughts: I've been using this cream, which is...         Oily
# 8   I've pretty much used at least 4 sets of these...         Oily
# 9   I had purchased this in a shady skinfood brick...         Oily
# 10  Thoughts I got this to deal with small wrinkle...         Oily
# 11  This foam cleanser stripped every bit of moist...         Oily
# 12  Thoughts: I am not saying this is the BEST sun...         Oily
# 13  \nSkin type Dry, flaky, very sensitive, rosace...          Dry
# 14  Thoughts: Found & bought a sample online and h...          Dry
# 15  Thoughts: For the last six months I've been ba...          Dry
# 16  She does an abbreviated or full 7 skin with th...          Dry
# 17  Thoughts: I love this moisturizer! It's rich a...          Dry
# 18  THOUGHTS: This is truly a hidden gem. I have n...          Dry
# 19  THOUGHTS: Lightly foaming soap that is soothin...          Dry
# 20  \nI have some of the driest skin I've ever hea...          Dry
# 21  This stuff is my HG of cleaning balms. Once yo...          Dry
# 22  Thoughts: I got a small sample from sephora tr...          Dry
# 23  THOUGHTS: This dried me out as well and left a...          Dry
# 24  Skin type Dry and thin.  Mild rosacea, prone t...          Dry
# 25  THOUGHTS I purchased this because I've read an...          Dry
# 26  I love this sleeping pack because I have dry, ...          Dry
# 27  I like this a lot. As directed, I used this on...          Dry
# 28  THOUGHTS:  Nowhere near as good as the essence...          Dry
# 29  Thoughts It's a very gentle cleanser but it's ...  Combination
# 30  Thoughts I like this aloe gel as much as the N...  Combination
# 31  Thoughts This cleanser in stick format is a fa...  Combination
# 32  Thoughts \nCopy paste from the Oily skin threa...  Combination
# 33  Thoughts I've actually only used a sample of t...  Combination
# 34  Thoughts This is a super lightweight moisturis...  Combination
# 35  Thoughts It's lightweight, but it packs a lot ...  Combination
# 36                                           Thoughts  Combination
# 37  Thoughts Literally, this is my HG cream to sea...  Combination
# 38  Thoughts If you have a whitehead which you've ...         Acne
# 39  This is amazing for calming active acne, reduc...         Acne
# 40  Thoughts. This is a lightweight hydrating esse...         Acne
# 41                                           Thoughts         Acne
# 42  This product has helped me so much with rednes...         Acne
# 43  Thoughts I've only been using it for two weeks...         Acne
# 44  I cannot stop raving about this product. It's ...         Acne
# 45  Thoughts I recommended this for oily skin and ...         Acne
# 46  Thoughts. This is more gentle than some wester...         Acne
# 47  This is old news to most folks here but its so...         Acne
# 48  Thoughts: I love this product- when I break ou...         Acne
# 49  If I have a skin freak out, I LOVE to do this ...         Acne
# 50  Thoughts: I highly recommend this for those wi...         Acne
# 51  This cleanser changed my skin so so much that ...         Acne
# 52  I had a few clogs on my forehead that weren't ...         Acne
# 53  thoughts. This is great at helping my blemishe...         Acne
# 54  Or really any mandelic acid product, but Dr. W...         Acne

# %% [markdown]
# Experiemnting on how to get a comment forest (the replies to a comment).  Since there are only 54 items in the list and I want to be able to quantify the popularity of a product by applying sentiment analysis on the comments to see if it's a positive comment or negative.

# %%
sid = SentimentIntensityAnalyzer()
for comment in submission.comments:
    comment.refresh()
    for reply in comment.replies:
        print(reply.body)
        ss = sid.polarity_scores(reply.body)
        for k in ss:
            print( "{0}: {1}," .format(k, ss[k]), end=" ")
            print()
# Out:
# Just because I know some people have questions, here is some helpful info on hydrocolloid patches. (Copy+paste from another comment of mine)
#
# I've noticed some misunderstanding around various skin care subs about what, exactly, hydrocolloid bandages do. They don't actually suck the gunk out of pimples!  Initially, they were made for blisters before being repurposed for acne. They absorb moisture from the wound to form a gel, which is why the bandage rapidly turns into a soft and spongy mass which also cushions your wound. The gel on the bandage is also cohesive, which means it creates a seal and whatever leaks from your wound stays in place under the dressing, allowing the wound to heal quicker. So the white stuff on the bandage isn't pus or anything, it is the moisture of the wound interacting with hydrocolloid on the bandage, causing the white appearance. This also makes sense with why they suggest the wound to already by open in some form as the bandage needs to interact with fluid in order to properly form a seal. Once the bandage is mostly white you're supposed to change it because it will become permeable to outside moisture as the seal is broken. With this in mind, it is good to note that hydrocolloid bandages are not an effective means to combat CCs.
#
# I totally wish that they sucked pus and gunk out of blemishes, but that is neither their purpose nor how they work, and therefore not what you're seeing happening with the bandage. They allow the wound to heal quicker and in a better environment.
#
# [Here](https://m.imgur.com/a/8SvWn) is a nice imgur gallery made by another user with more info and pics!
#
# Edit: wording/grammar.
# neg: 0.032,
# neu: 0.896,
# pos: 0.072,
# compound: 0.8849,
# I've tried using this and maybe I'm just doing it wrong? I lance it but don't squeeze and then put on the patch for the night, but when I wake up the zit is still there. So I put it on for another day/night and it just ends up becoming an under the skin pimple again but bigger. Wtf
# neg: 0.118,
# neu: 0.882,
# pos: 0.0,
# compound: -0.8047,
# That is my go-to product whenever I have that huge red pimple! I have at least 5 packs of this in my drawer to make sure I always have one for emergencies :D
# neg: 0.0,
# neu: 0.744,
# pos: 0.256,
# compound: 0.837,
# These are my favorite. I've been using them for a while but it still feels like magic when I put them on before bed and the spot is flat in the morning. Out of curiosity, what blemish cream do you like to use after one of these?
# neg: 0.0,
# neu: 0.832,
# pos: 0.168,
# compound: 0.8176,
# This stuff is seriously the best!!
# neg: 0.162,
# neu: 0.382,
# pos: 0.456,
# compound: 0.6229,
# Snail products break me out, but I so want to use them! Does anyone else have that problem?
# neg: 0.183,
# neu: 0.716,
# pos: 0.101,
# compound: -0.4079,
# Love this stuff!
# neg: 0.0,
# neu: 0.308,
# pos: 0.692,
# compound: 0.6696,
# How would you compare it to Cosrx one? I just finished my Benton essence and looking to get a new one. It's either this again (not sure if it helped my acnes) or Cosrx's snail essence.
# neg: 0.0,
# neu: 0.935,
# pos: 0.065,
# compound: 0.3182,
# Same for me. I use it in the evening before my sleeping mask and in just one night it helps so much to heal any acne especially inflammation. I was really not expected it to be so beneficial.
# neg: 0.0,
# neu: 0.843,
# pos: 0.157,
# compound: 0.7462,
# I mostly just find it super soothing and helps calm down things after I've gotten them red and irritated.
# neg: 0.111,
# neu: 0.48,
# pos: 0.41,
# compound: 0.7964,
# This, a hundred times this.
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# This is the first product that I've ever felt comfortable calling a holy grail. My skin has improved so much since I discovered this.
# neg: 0.0,
# neu: 0.758,
# pos: 0.242,
# compound: 0.7506,
# Yes! Absolutely love this! Sometimes I feel like it does nothing, but like you said I notice a difference when I stop using it.
# neg: 0.1,
# neu: 0.536,
# pos: 0.364,
# compound: 0.7492,
# I've found good deals for this on Amazon. I use this every morning!
# neg: 0.0,
# neu: 0.672,
# pos: 0.328,
# compound: 0.5983,
# Have you ever tried the UNIK Tea Tree Relief Serum? It has less tea tree water (replaces it with centella) but is way cheaper.
# neg: 0.0,
# neu: 0.918,
# pos: 0.082,
# compound: 0.2617,
# Second!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# First hint of a potential pimple and this goes on! Helps reduce the intensity of the pimple when it forms, and sometimes even just completely heals the spot before the pimple could form.
# neg: 0.0,
# neu: 0.915,
# pos: 0.085,
# compound: 0.4389,
# Yes! I recently got this and it calms new acne almost instantaneously!
# neg: 0.0,
# neu: 0.617,
# pos: 0.383,
# compound: 0.6792,
# Do you have leftover Klairs toner? I'd buy it off of you!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Do you happen to know the difference between the super volcanic and the jeju?
# neg: 0.0,
# neu: 0.769,
# pos: 0.231,
# compound: 0.5994,
# I've tried this product as well. It makes my skin really clean and feels soft after using it. It's really good in cleansing without irritating your skin. However, I find it hard to apply and yes, it kinda messy to wash off. And also, some people claim that this product will heal/shrink your acne, but that didn't happen to me. This product didn't break me out, but it wasn't able to help me reduce my acne either. Overall, it's a good deep cleansing product for me.
# neg: 0.06,
# neu: 0.796,
# pos: 0.144,
# compound: 0.7803,
# Yes, I love this clay mask!
#
# I have tried some other ones in the past. Kiehl's, Borghese (the green-ish one), origins (my friend let me borrow it), and sanctuary (which is actually perfect if your skin is drier/more sensitive since it is a lot gentler than other clay masks), but the innisfree one works very well, and is quite inexpensive for how well it works.
#
# I have very severe blackheads (so severe you won't believe), but a round of clay mask, then a thick layer of Annie's Way arbutin + hyaluronic acid mask, and they are barely visible, which is amazing!
#
# On the other hand, I find my clay mask getting hard after a while. It is still usable, but difficult to spread on lol. Any ideas how to counteract this?
# neg: 0.083,
# neu: 0.715,
# pos: 0.202,
# compound: 0.9519,
# But i don't know whether my skin isn't suitable for that clay mask or not.I dindn't see any cleansing result on my face, but i can feel more cleaner than before.What's more, it;s hard and messy to apply for its texture.It always cost me lots of time to clean out.
# neg: 0.095,
# neu: 0.796,
# pos: 0.109,
# compound: 0.1955,
# I literally just got this in the mail yesterday and tried it last night. Having sensitive combo skin sucks because I have these deep CCs but acids make my face red and itchy. You have no idea how shocked I was this morning to find the CCs visibly smaller. Like I expected a two week time frame. That said this afternoon they're back to about normalish size but holy cow I wasn't expecting that. No stinging itchy areas either. Never would have given acids another go if it hadn't been for this sub!
#
# Also the translation on the box says something to the effect "You had better" which makes me chuckle.
# neg: 0.105,
# neu: 0.786,
# pos: 0.109,
# compound: 0.3557,
# How does this compare with the CosRX AHA?
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# +1 on this. It's amazing for blackheads, whiteheads and CCs. I use this twice a week and it makes my skin so smooth. I wouldn't recommend using it more than that. My skin can handle a LOT with actives, but this AHA wrecks my skin if I use it more than 2 times a week. Better to alternate with a BHA every few days.
# neg: 0.027,
# neu: 0.846,
# pos: 0.127,
# compound: 0.728,
# shark week +1
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Does anyone have a comparison between this and The Ordinary 10% Lactic Acid?
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# [deleted]
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# I actually use this on my armpits :D Besides being really effective in preventing pimples, I also find this useful as a first aid whenever my face becomes itchy due to some allergic reaction to the food I ate. **I'm not saying** this could replace skin allergy medicine, but it's a good temporary relief when you ran out of skin allergy ointment.
# neg: 0.063,
# neu: 0.718,
# pos: 0.218,
# compound: 0.9112,
# This product actually breaks me out like crazy and I wasn't sure what to do with it since I still have like 3/4ths of it left, but using it on my armpits sounds like a really good idea!!
# neg: 0.073,
# neu: 0.662,
# pos: 0.265,
# compound: 0.8571,
# I use this too, mixed with a couple drops of TTO and it can zap a pretty nasty breakout. I will often do an exfoliation step before if it is for general maintenance versus single breakout. I have been using this mask since before my AB days, almost 5+ years now. I have no idea how I found it. I follow with foaming cleanser to get the gunk out, than the rest of my routine per normal, often with a sheet mask to get hydration back into my skin.
#
# I prefer this mask because it is really affordable and will never dry out, since it comes as a powder.
#
# I also have used just the powder on my face when I am really red to set makeup (if I am even wearing any) or just as a color correcting and mattifying powder. *I don't have perfect skin, just lazy AF so not big into makeup although moving to an AB style skin routine over the last 8ish months has cleared my skin considerably.
# neg: 0.067,
# neu: 0.905,
# pos: 0.027,
# compound: -0.7716,
# I've had the same results. It helps heal existing pimples but more importantly I've had a much lower amount of fresh spots since starting this. I tone, then use the COSrx Blackhead Power Liquid BHA, then use this and I've seen a drastic improvement.
# neg: 0.055,
# neu: 0.707,
# pos: 0.238,
# compound: 0.8534,
# I use this in the morning to help control my sebum production. I am definitely going to repurchase, but I have only used it during the summer, so I might have to make a change for winter/fall.
#
# Love It's Skin serums. Good price and really effective. I have also been using the VC (vitamin C) in this line at night when I am not using CorsRx AHA or BHA. I have plans to try some of the other serums in the line, aka saved a bunch on an Amazon list.
# neg: 0.0,
# neu: 0.758,
# pos: 0.242,
# compound: 0.9741,
# oh man! i'm so sorry to hear that :(
# i actually love the all clean balm (save for it's annoying unhygienic packaging fml) and i use it everyday as my first oil cleanser!
# neg: 0.194,
# neu: 0.637,
# pos: 0.169,
# compound: 0.283,
# same here. broke me out.  I'm back to banilla co
# neg: 0.237,
# neu: 0.763,
# pos: 0.0,
# compound: -0.4215,
# YES. Obsessed with this stuff. It has changed my life and my skin for the better. It's done wonders for my shoulder acne.
# neg: 0.061,
# neu: 0.713,
# pos: 0.226,
# compound: 0.6841,
# Ah...I see this is the blemish cream you like. Whoops.
# neg: 0.0,
# neu: 0.783,
# pos: 0.217,
# compound: 0.3612,
# Probably best to ask this in the daily help thread x
# neg: 0.0,
# neu: 0.537,
# pos: 0.463,
# compound: 0.7845,

# %% [markdown]
# So the sentiment analyzer seems to work quite well! I'm going to add a positive count and negative count column to the data set to record the comments.

# %%
sid = SentimentIntensityAnalyzer()
data["pos_count"] = 0
data["neg_count"] = 0
data["neu_count"] = 0
count_row = len(data)

for i in range(0,count_row): 
    comment = reddit.comment(data['id'].iloc[i])
    comment.refresh()
    #print(comment.body)
    for reply in comment.replies:
        #print(reply.body)
        ss = sid.polarity_scores(reply.body)
        
        if ss["compound"] == 0.0:
            #print("neutral")
            data.loc[i, "neu_count" ] += 1
        elif ss["compound"] > 0.0:
            #print("postive")
            data.loc[i, "pos_count" ] += 1
        else:
            #print("neg")
            data.loc[i, "neg_count" ] += 1

# %%
data.head()
# Out:
#         id                                         product         step  \
# 0  djv0ax0              Innisfree Super Volcanic Clay Mask    Clay Mask
# 1  djv702q                                 Belif Aqua Bomb  Moisturizer
# 2  djv01bn                                 Blotting Papers        Tools
# 3  djv4eeq  Missha Super Aqua Ultra Water-Full Clear Cream  Moisturizer
# 4  djuzzcn               Innisfree No Sebum Powder - Loose      Make Up
#
#   opinion                                           thoughts thread  \
# 0    Best  Thoughts I use a clay mask at least once a wee...   Oily
# 1    Best  I love this stuff. It's a gel cream that sinks...   Oily
# 2    Best  Thoughts Not really a product as such, but I s...   Oily
# 3    Best  Thoughts Using this gel-type moisturizer at ni...   Oily
# 4    Best  Thoughts Love this affordable powder! I dust i...   Oily
#
#    pos_count  neg_count  neu_count
# 0          7          2          0
# 1          3          1          0
# 2          6          0          0
# 3          2          0          0
# 4          7          2          5

# %%
data = data.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)

data.loc[data['opinion'].str.contains("best"), 'pos_count'] = data['pos_count'] + 1
data.loc[data['opinion'].str.contains("worst"), 'pos_count'] = data['pos_count'] + 1


data
# Out:
#          id                                            product  \
# 0   djv0ax0                 innisfree super volcanic clay mask
# 1   djv702q                                    belif aqua bomb
# 2   djv01bn                                    blotting papers
# 3   djv4eeq     missha super aqua ultra water-full clear cream
# 4   djuzzcn                  innisfree no sebum powder - loose
# 5   djv05rw          elizavecca 24k gold water drop cream mask
# 6   djvlvej                           pyungkang yul mist toner
# 7   djvedyg            cosrx aloe vera oil-free moisture cream
# 8   djvpgxn        zymogen houttyunia cordata serum and lotion
# 9   djv8nyi                          neogen black volume cream
# 10  djvkyzy        the history of whoo wrinkle essentual cream
# 11  djvkgfh            shiseido pureness deep cleansing foam
# 12  djwf33s  country & stream honey uv water gel spf50+ pa++++
# 13  dk8cjho                              hada labo perfect gel
# 14  dk8mlx7                  product name: stratia liquid gold
# 15  dk8a8it                                        rosehip oil
# 16  dk870gv                          pyukang yul essence toner
# 17  dk9cye8                     product: mizon black snail aio
# 18  dk8c0g5     product name: koh gen do oriental plants soap
# 19  dk8c85m  product name: sulwhasoo snowise ex cleansing f...
# 20  dk8vqob   lost and found seoul med.secret cream + ceramide
# 21  dk8mrvd      botanic farm grain ferment cleansing sherbet
# 22  dk80ops                shiseido ibuki beauty sleeping mask
# 23  dk8bs0a     product name: shisheido perfect cleansing oil
# 24  dk837ry  shiseido bio-performance advanced super revita...
# 25  dk9i3gu              product whamisa organic flowers toner
# 26  dk8maj3              innisfree rice sleeping pack capsule
# 27  dkirecs                     i'm from ginseng wash off mask
# 28  dk8bnmi          product name: sk-ii facial treatment soap
# 29  dlt6v7f          innisfree bija anti-trouble cleansing gel
# 30  dlt7ebc                         holika holika 99% aloe gel
# 31  dlswn2m                 su:m37 miracle rose stick cleanser
# 32  dlswt9s                 innisfree super volcanic clay mask
# 33  dlt71q4          banila co miss flower and mr. honey cream
# 34  dlswkk5   elizavecca 24k gold waterdrop & 2hsam cream mask
# 35  dluk1za                     mizon snail recovery gel cream
# 36  dlvkm71          huxley oil essence essence-like, oil-like
# 37  dlzz95c          benton snail bee high content steam cream
# 38  dl4g1ts                          cosrx master pimple patch
# 39  dl4smbh                           benton snail bee essence
# 40  dl4fpug                               ljh tea tree essence
# 41  dl4lm63                      stratia velvet cleansing milk
# 42  dl4mqbi                       cosrx centella blemish cream
# 43  dl56j0g                          cosrx bha returning a-sol
# 44  dl56o6v                           scinic snail aio ampoule
# 45  dl4fm93                 innisfree super volcanic clay mask
# 46  dl4ft4h                                       mizon 8% aha
# 47  dl58nqw                       cosrx 96 snail mucin essence
# 48  dl53cf7              cosrx acne one step pimple clear pads
# 49  dl80usl                            aztec healing clay mask
# 50  dl4o1c9  it's skin power 10 formula vb effector with vi...
# 51  dl9doxx             cosrx good morning low ph gel cleanser
# 52  dl5zi0c                     mizon snail recovery gel cream
# 53  dl4fyfm  mizon acence blemish x cream (i think, not at ...
# 54  dlguq74  mandelic acid- dr. wu's 18% aha skin renewal s...
#
#                                       step  \
# 0                                clay mask
# 1                              moisturizer
# 2                                    tools
# 3                              moisturizer
# 4                                  make up
# 5                              moisturiser
# 6                          hydrating toner
# 7                              moisturizer
# 8                    toner and moisturiser
# 9                sleeping pack/moisturizer
# 10           special needs/cream/eye cream
# 11                              cleanser
# 12                               sunscreen
# 13        \nmoisturiser (or sleeping pack)
# 14  step: moisturiser/last step occlusive
# 15                             moisturizer
# 16                                   toner
# 17                             moisturizer
# 18                          step: cleanser
# 19                         step: cleanser
# 20                           \nmoisturizer
# 21                      1st step cleanser
# 22                             moisturiser
# 23                          step: cleanser
# 24                             moisturizer
# 25                                  toner
# 26                             moisturizer
# 27                     wash-off detox mask
# 28                         step: cleanser
# 29                                cleanser
# 30                         gel moisturizer
# 31                                cleanser
# 32                               clay mask
# 33                               occlusive
# 34                             moisturiser
# 35                             moisturizer
# 36                                 essence
# 37                                   cream
# 38                          spot treatment
# 39                                 essence
# 40                                 essence
# 41                         second cleanser
# 42                                   cream
# 43                            essence step
# 44                                 ampoule
# 45                               clay mask
# 46                      chemical exfoliant
# 47                                 essence
# 48                      chemical exfoliant
# 49                                    mask
# 50                                   serum
# 51                         second cleanser
# 52                     spot treatment step
# 53                              spot cream
# 54                                 actives
#
#                                               opinion  \
# 0                                                best
# 1                                                best
# 2                                                best
# 3                                                best
# 4                                                best
# 5                                                best
# 6                                                best
# 7                                                best
# 8                                                best
# 9                                                best
# 10                                              worst
# 11                                            worst
# 12                                               best
# 13                                            \nbest
# 14                                               best
# 15  best for immediate relief from stretches of he...
# 16  best for my dear friend who has problematic dr...
# 17                                               best
# 18                                               best
# 19                                               best
# 20                                             \nbest
# 21                                               best
# 22                                              worst
# 23                                             worst
# 24                                        best for me
# 25                                              worst
# 26                                               best
# 27                                               best
# 28                                              worst
# 29                                               best
# 30                                               best
# 31                                               best
# 32                                               best
# 33                                               best
# 34                                               best
# 35                                               best
# 36                                               best
# 37                                               best
# 38                                               best
# 39                                               best
# 40                                              best
# 41                                               best
# 42                                               best
# 43                                               best
# 44                                               best
# 45                                               best
# 46                                               best
# 47                                             best
# 48                                             best!!
# 49                                               best
# 50                                               best
# 51                                               best
# 52                                               best
# 53                                               best
# 54                                               best
#
#                                              thoughts       thread  pos_count  \
# 0   thoughts i use a clay mask at least once a wee...         oily          8
# 1   i love this stuff. it's a gel cream that sinks...         oily          4
# 2   thoughts not really a product as such, but i s...         oily          7
# 3   thoughts using this gel-type moisturizer at ni...         oily          3
# 4   thoughts love this affordable powder! i dust i...         oily          8
# 5   thoughts this is a lightweight gel from elizav...         oily          1
# 6   thoughts: this product is how i'm surviving su...         oily          3
# 7   thoughts: i've been using this cream, which is...         oily          2
# 8   i've pretty much used at least 4 sets of these...         oily          1
# 9   i had purchased this in a shady skinfood brick...         oily          1
# 10  thoughts i got this to deal with small wrinkle...         oily          1
# 11  this foam cleanser stripped every bit of moist...         oily          1
# 12  thoughts: i am not saying this is the best sun...         oily          2
# 13  \nskin type dry, flaky, very sensitive, rosace...          dry          6
# 14  thoughts: found & bought a sample online and h...          dry          5
# 15  thoughts: for the last six months i've been ba...          dry          3
# 16  she does an abbreviated or full 7 skin with th...          dry          3
# 17  thoughts: i love this moisturizer! it's rich a...          dry          1
# 18  thoughts: this is truly a hidden gem. i have n...          dry          1
# 19  thoughts: lightly foaming soap that is soothin...          dry          1
# 20  \ni have some of the driest skin i've ever hea...          dry          1
# 21  this stuff is my hg of cleaning balms. once yo...          dry          2
# 22  thoughts: i got a small sample from sephora tr...          dry          2
# 23  thoughts: this dried me out as well and left a...          dry          3
# 24  skin type dry and thin.  mild rosacea, prone t...          dry          1
# 25  thoughts i purchased this because i've read an...          dry          2
# 26  i love this sleeping pack because i have dry, ...          dry          1
# 27  i like this a lot. as directed, i used this on...          dry          1
# 28  thoughts:  nowhere near as good as the essence...          dry          1
# 29  thoughts it's a very gentle cleanser but it's ...  combination          2
# 30  thoughts i like this aloe gel as much as the n...  combination          3
# 31  thoughts this cleanser in stick format is a fa...  combination          4
# 32  thoughts \ncopy paste from the oily skin threa...  combination          2
# 33  thoughts i've actually only used a sample of t...  combination          3
# 34  thoughts this is a super lightweight moisturis...  combination          1
# 35  thoughts it's lightweight, but it packs a lot ...  combination          1
# 36                                           thoughts  combination          1
# 37  thoughts literally, this is my hg cream to sea...  combination          1
# 38  thoughts if you have a whitehead which you've ...         acne          5
# 39  this is amazing for calming active acne, reduc...         acne          5
# 40  thoughts. this is a lightweight hydrating esse...         acne          5
# 41                                           thoughts         acne          1
# 42  this product has helped me so much with rednes...         acne          1
# 43  thoughts i've only been using it for two weeks...         acne          3
# 44  i cannot stop raving about this product. it's ...         acne          1
# 45  thoughts i recommended this for oily skin and ...         acne          5
# 46  thoughts. this is more gentle than some wester...         acne          3
# 47  this is old news to most folks here but its so...         acne          1
# 48  thoughts: i love this product- when i break ou...         acne          3
# 49  if i have a skin freak out, i love to do this ...         acne          1
# 50  thoughts: i highly recommend this for those wi...         acne          3
# 51  this cleanser changed my skin so so much that ...         acne          1
# 52  i had a few clogs on my forehead that weren't ...         acne          2
# 53  thoughts. this is great at helping my blemishe...         acne          2
# 54  or really any mandelic acid product, but dr. w...         acne          1
#
#     neg_count  neu_count
# 0           2          0
# 1           1          0
# 2           0          0
# 3           0          0
# 4           2          5
# 5           0          0
# 6           1          0
# 7           0          0
# 8           0          0
# 9           0          0
# 10          0          0
# 11          0          0
# 12          0          0
# 13          0          0
# 14          0          0
# 15          1          0
# 16          0          1
# 17          1          0
# 18          0          0
# 19          0          0
# 20          0          1
# 21          0          0
# 22          1          0
# 23          0          0
# 24          1          0
# 25          0          0
# 26          0          0
# 27          0          0
# 28          0          0
# 29          1          0
# 30          0          0
# 31          2          0
# 32          0          0
# 33          1          0
# 34          0          0
# 35          0          0
# 36          1          0
# 37          0          0
# 38          1          0
# 39          1          0
# 40          0          1
# 41          0          0
# 42          0          1
# 43          0          1
# 44          0          0
# 45          0          0
# 46          0          3
# 47          0          1
# 48          0          0
# 49          1          0
# 50          0          0
# 51          0          0
# 52          0          0
# 53          0          0
# 54          0          0

# %%
data.to_csv("skincare.csv", encoding='utf-8', index=False)
